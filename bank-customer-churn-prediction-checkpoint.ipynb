# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
drop = ['RowNumber', 'CustomerId', 'Surname','Geography']
df.drop(columns=drop,inplace=True)

# %%
df.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619  Female   42       2       0.00              1          1
# 1          608  Female   41       1   83807.86              1          0
# 2          502  Female   42       8  159660.80              3          1
# 3          699  Female   39       1       0.00              2          0
# 4          850  Female   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Gender           10000 non-null  object
#  2   Age              10000 non-null  int64
#  3   Tenure           10000 non-null  int64
#  4   Balance          10000 non-null  float64
#  5   NumOfProducts    10000 non-null  int64
#  6   HasCrCard        10000 non-null  int64
#  7   IsActiveMember   10000 non-null  int64
#  8   EstimatedSalary  10000 non-null  float64
#  9   Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 781.4+ KB

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
gender = {'Male':1,'Female':0}
df['Gender'] = df['Gender'].map(gender)
df.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
df['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Gender           10000 non-null  int64
#  2   Age              10000 non-null  int64
#  3   Tenure           10000 non-null  int64
#  4   Balance          10000 non-null  float64
#  5   NumOfProducts    10000 non-null  int64
#  6   HasCrCard        10000 non-null  int64
#  7   IsActiveMember   10000 non-null  int64
#  8   EstimatedSalary  10000 non-null  float64
#  9   Exited           10000 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 781.4 KB

# %%
correlation = df[['CreditScore',
       'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary', 'Exited']].corr()

# %%
plt.figure(figsize = (10,5))
sns.heatmap(data=correlation, annot=True)
# Out:
# <Axes: >

# %%
df_1 = df[df.Exited==1]
df_1.shape
# Out:
# (2037, 10)

# %%
numerical_columns = df_1.select_dtypes(include=['number']).columns

# Number of numerical columns
num_plots = len(numerical_columns)

# Create subplots with enough space for each numerical column
plt.figure(figsize=(15, 5 * num_plots))

# Plot boxplots for each numerical column
for idx, column in enumerate(numerical_columns):
    plt.subplot(num_plots, 1, idx + 1)  # Create a subplot for each column
    sns.boxplot(data=df_1, x=column)  # Plot the boxplot
    plt.title(f'Boxplot for {column}')  # Add a title to each subplot

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
def remove_outliers_iqr(df):
    # Copy the DataFrame to avoid modifying the original data
    df_cleaned = df.copy()

    # List to store columns that are numerical
    numerical_columns = df_cleaned.select_dtypes(include=['number']).columns

    # Iterate over each numerical column
    for column in numerical_columns:
        # Calculate Q1 (25th percentile) and Q3 (75th percentile)
        Q1 = df_cleaned[column].quantile(0.25)
        Q3 = df_cleaned[column].quantile(0.75)
        # Calculate IQR (Interquartile Range)
        IQR = Q3 - Q1
        # Define bounds for outliers
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Filter out the outliers
        df_cleaned = df_cleaned[(df_cleaned[column] >= lower_bound) & (df_cleaned[column] <= upper_bound)]

    return df_cleaned

# Remove outliers from df_1
df_1_cleaned = remove_outliers_iqr(df_1)

# %%
df_1_cleaned.reset_index(drop=True)
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             502       0   42       8  159660.80              3          1
# 2             645       1   44       8  113755.78              2          1
# 3             653       1   58       1  132602.88              1          1
# 4             510       0   38       4       0.00              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 1948          498       1   42       3  152039.70              1          1
# 1949          655       0   46       7  137145.12              1          1
# 1950          597       0   53       4   88381.21              1          1
# 1951          709       0   36       7       0.00              1          0
# 1952          772       1   42       3   75075.31              2          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  0        113931.57       1
# 2                  0        149756.71       1
# 3                  0          5097.67       1
# 4                  0        118913.53       1
# ...              ...              ...     ...
# 1948               1         53445.17       1
# 1949               0        115146.40       1
# 1950               0         69384.71       1
# 1951               1         42085.58       1
# 1952               0         92888.52       1
#
# [1953 rows x 10 columns]

# %%
df_1_cleaned.shape
# Out:
# (1953, 10)

# %%
df_0 = df[df['Exited']==0]

# %%
df_0.shape
# Out:
# (7963, 10)

# %%
numerical_columns = df_0.select_dtypes(include=['number']).columns

# Number of numerical columns
num_plots = len(numerical_columns)

# Create subplots with enough space for each numerical column
plt.figure(figsize=(15, 5 * num_plots))

# Plot boxplots for each numerical column
for idx, column in enumerate(numerical_columns):
    plt.subplot(num_plots, 1, idx + 1)  # Create a subplot for each column
    sns.boxplot(data=df_0, x=column)  # Plot the boxplot
    plt.title(f'Boxplot for {column}')  # Add a title to each subplot

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()  # Show all plots

# %%
df_0_cleaned = remove_outliers_iqr(df_0)

# %%
df_0_cleaned.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 1          608       0   41       1   83807.86              1          0
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
# 6          822       1   50       7       0.00              2          1
# 8          501       1   44       4  142051.07              2          0
#
#    IsActiveMember  EstimatedSalary  Exited
# 1               1        112542.58       0
# 3               0         93826.63       0
# 4               1         79084.10       0
# 6               1         10062.80       0
# 8               1         74940.50       0

# %%
df_0_cleaned.shape
# Out:
# (7477, 10)

# %%
df_0_cleaned = df_0_cleaned.sample(n = 1953 , random_state=1)

# %%
df_combined = pd.concat([df_1_cleaned, df_0_cleaned],axis=0)

# %%
df_combined.head()
# Out:
#     CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0           619       0   42       2       0.00              1          1
# 2           502       0   42       8  159660.80              3          1
# 5           645       1   44       8  113755.78              2          1
# 16          653       1   58       1  132602.88              1          1
# 22          510       0   38       4       0.00              1          1
#
#     IsActiveMember  EstimatedSalary  Exited
# 0                1        101348.88       1
# 2                0        113931.57       1
# 5                0        149756.71       1
# 16               0          5097.67       1
# 22               0        118913.53       1

# %%
df_combined.tail()
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6927          601       0   37       5       0.00              1          0
# 2767          598       0   27      10  171283.91              1          1
# 3679          650       1   25       7  160599.06              2          1
# 7757          850       1   40       6   97339.99              1          0
# 8791          725       0   25       9       0.00              2          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 6927               0         20708.60       0
# 2767               1         84136.12       0
# 3679               1         28391.52       0
# 7757               1         88815.25       0
# 8791               1        168607.74       0

# %%
df_combined.reset_index(drop=True)
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             502       0   42       8  159660.80              3          1
# 2             645       1   44       8  113755.78              2          1
# 3             653       1   58       1  132602.88              1          1
# 4             510       0   38       4       0.00              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 3901          601       0   37       5       0.00              1          0
# 3902          598       0   27      10  171283.91              1          1
# 3903          650       1   25       7  160599.06              2          1
# 3904          850       1   40       6   97339.99              1          0
# 3905          725       0   25       9       0.00              2          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  0        113931.57       1
# 2                  0        149756.71       1
# 3                  0          5097.67       1
# 4                  0        118913.53       1
# ...              ...              ...     ...
# 3901               0         20708.60       0
# 3902               1         84136.12       0
# 3903               1         28391.52       0
# 3904               1         88815.25       0
# 3905               1        168607.74       0
#
# [3906 rows x 10 columns]

# %%
df_combined.columns
# Out:
# Index(['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
X = df_combined.drop('Exited',axis=1)
y = df_combined['Exited']

# %%
print(X)
print(y)
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 2             502       0   42       8  159660.80              3          1
# 5             645       1   44       8  113755.78              2          1
# 16            653       1   58       1  132602.88              1          1
# 22            510       0   38       4       0.00              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 6927          601       0   37       5       0.00              1          0
# 2767          598       0   27      10  171283.91              1          1
# 3679          650       1   25       7  160599.06              2          1
# 7757          850       1   40       6   97339.99              1          0
# 8791          725       0   25       9       0.00              2          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 2                  0        113931.57
# 5                  0        149756.71
# 16                 0          5097.67
# 22                 0        118913.53
# ...              ...              ...
# 6927               0         20708.60
# 2767               1         84136.12
# 3679               1         28391.52
# 7757               1         88815.25
# 8791               1        168607.74
#
# [3906 rows x 9 columns]
# 0       1
# 2       1
# 5       1
# 16      1
# 22      1
#        ..
# 6927    0
# 2767    0
# 3679    0
# 7757    0
# 8791    0
# Name: Exited, Length: 3906, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,stratify=y,random_state=1)

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3906 entries, 0 to 8791
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      3906 non-null   int64
#  1   Gender           3906 non-null   int64
#  2   Age              3906 non-null   int64
#  3   Tenure           3906 non-null   int64
#  4   Balance          3906 non-null   float64
#  5   NumOfProducts    3906 non-null   int64
#  6   HasCrCard        3906 non-null   int64
#  7   IsActiveMember   3906 non-null   int64
#  8   EstimatedSalary  3906 non-null   float64
#  9   Exited           3906 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 335.7 KB

# %%
mm = MinMaxScaler()

# %%
num_columns = ['CreditScore','Age', 'Tenure', 'Balance', 'EstimatedSalary']
X_train[num_columns] = mm.fit_transform(X_train[num_columns])
X_test[num_columns] = mm.transform(X_test[num_columns])

# %%
lr_clf = LogisticRegression(random_state=1)
lr_clf.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
y_lr_pred = lr_clf.predict(X_test)
lr_scores = cross_val_score(lr_clf,X_train,y_train,cv=5)
print(lr_scores)
print(lr_scores.mean())
print(accuracy_score(y_test,y_lr_pred))
# Out:
# [0.74914676 0.72696246 0.72866894 0.72354949 0.72478632]
# 0.7306227939675038
# 0.7134083930399181

# %%
neighbors = [3,5,7,9,11]
scores = []
for i in neighbors:
    knn_clf = KNeighborsClassifier(n_neighbors = i)
    knn_clf.fit(X_train,y_train)
    knn_scores = cross_val_score(knn_clf,X_train,y_train,cv=5)
    print(knn_scores.mean())
    knn_predict = knn_clf.predict(X_test)
    scores.append(accuracy_score(y_test,knn_predict))
    
scores = np.array(scores)
print(scores)
print(scores.mean())
# Out:
# 0.7142387911671189
# 0.7227735480295208
# 0.7258469706251276
# 0.7234549750590705
# 0.7238009392958198
# [0.72262027 0.72978506 0.73183214 0.74411464 0.74002047]
# 0.7336745138178096

# %%
knn_clf = KNeighborsClassifier(n_neighbors=7)
knn_clf.fit(X_train,y_train)
knn_pred = knn_clf.predict(X_test)
print(accuracy_score(y_test,knn_pred))
# Out:
# 0.7318321392016377

# %%
svm_clf = SVC(kernel = 'poly',random_state=1)
svm_clf.fit(X_train,y_train)
svm_scores = cross_val_score(svm_clf,X_train,y_train,cv=5)
print(svm_scores)
print(svm_scores.mean())
# Out:
# [0.78156997 0.75938567 0.77986348 0.73890785 0.75213675]
# 0.762372742918818

# %%
svm_pred = svm_clf.predict(X_test)
print(accuracy_score(y_test,svm_pred))
# Out:
# 0.7471852610030706

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(9,)),  # Input layer with 9 features
    tf.keras.layers.Dense(64, activation='relu'),  # Hidden layer
    tf.keras.layers.Dense(32, activation='relu'),  # Another hidden layer
    tf.keras.layers.Dense(2, activation='softmax')  # Output layer for binary classification
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',  # For multi-class classification
    metrics=['accuracy']
)

# Train the model
model.fit(X_train, y_train, epochs=100, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc}")

# Make predictions
predictions = model.predict(X_test)
print(f"Predicted label for the first test case: {tf.argmax(predictions[0])}")
# Out:
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6205 - loss: 0.6610 - val_accuracy: 0.6604 - val_loss: 0.6100
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7074 - loss: 0.5718 - val_accuracy: 0.6689 - val_loss: 0.5746
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7133 - loss: 0.5443 - val_accuracy: 0.6894 - val_loss: 0.5665
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7448 - loss: 0.5148 - val_accuracy: 0.7082 - val_loss: 0.5395
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7498 - loss: 0.4990 - val_accuracy: 0.7201 - val_loss: 0.5437
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7399 - loss: 0.5038 - val_accuracy: 0.7304 - val_loss: 0.5300
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7402 - loss: 0.4980 - val_accuracy: 0.7304 - val_loss: 0.5281
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8105 - loss: 0.3945 - val_accuracy: 0.7474 - val_loss: 0.4961
# Epoch 74/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8060 - loss: 0.4047 - val_accuracy: 0.7526 - val_loss: 0.4846
# Epoch 75/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8174 - loss: 0.3981 - val_accuracy: 0.7560 - val_loss: 0.4836
# Epoch 76/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8061 - loss: 0.3984 - val_accuracy: 0.7611 - val_loss: 0.4988
# Epoch 77/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.4089 - val_accuracy: 0.7594 - val_loss: 0.4871
# Epoch 78/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8142 - loss: 0.3940 - val_accuracy: 0.7577 - val_loss: 0.4850
# Epoch 79/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8188 - loss: 0.3928 - val_accuracy: 0.7611 - val_loss: 0.4891
# Epoch 80/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8231 - loss: 0.3860 - val_accuracy: 0.7440 - val_loss: 0.5115
# Epoch 81/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.4009 - val_accuracy: 0.7509 - val_loss: 0.4884
# Epoch 82/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7968 - loss: 0.4153 - val_accuracy: 0.7577 - val_loss: 0.4883
# Epoch 83/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7988 - loss: 0.4164 - val_accuracy: 0.7594 - val_loss: 0.4938
# Epoch 84/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7974 - loss: 0.4007 - val_accuracy: 0.7577 - val_loss: 0.4938
# Epoch 85/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8207 - loss: 0.4008 - val_accuracy: 0.7440 - val_loss: 0.5031
# Epoch 86/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8070 - loss: 0.3920 - val_accuracy: 0.7628 - val_loss: 0.4912
# Epoch 87/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7934 - loss: 0.4103 - val_accuracy: 0.7594 - val_loss: 0.4971
# Epoch 88/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8122 - loss: 0.4078 - val_accuracy: 0.7679 - val_loss: 0.4958
# Epoch 89/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.3842 - val_accuracy: 0.7611 - val_loss: 0.4969
# Epoch 90/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8157 - loss: 0.3887 - val_accuracy: 0.7594 - val_loss: 0.4910
# Epoch 91/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8111 - loss: 0.3859 - val_accuracy: 0.7645 - val_loss: 0.4929
# Epoch 92/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8224 - loss: 0.3888 - val_accuracy: 0.7628 - val_loss: 0.4919
# Epoch 93/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8064 - loss: 0.4022 - val_accuracy: 0.7628 - val_loss: 0.4960
# Epoch 94/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8273 - loss: 0.3780 - val_accuracy: 0.7543 - val_loss: 0.4884
# Epoch 95/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8259 - loss: 0.3827 - val_accuracy: 0.7611 - val_loss: 0.4921
# Epoch 96/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8235 - loss: 0.3930 - val_accuracy: 0.7679 - val_loss: 0.5000
# Epoch 97/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8008 - loss: 0.4041 - val_accuracy: 0.7611 - val_loss: 0.5043
# Epoch 98/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8159 - loss: 0.3892 - val_accuracy: 0.7594 - val_loss: 0.4866
# Epoch 99/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8263 - loss: 0.3799 - val_accuracy: 0.7491 - val_loss: 0.5053
# Epoch 100/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8232 - loss: 0.3763 - val_accuracy: 0.7560 - val_loss: 0.4946
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7842 - loss: 0.4623
# Test accuracy: 0.7502558827400208
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Predicted label for the first test case: 0

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt_clf.predict(X_test)
print(accuracy_score(y_test,dt_pred))
# Out:
# 0.6847492323439099

# %%
rf_clf = RandomForestClassifier(random_state=7)
rf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=7)

# %%
rf_pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,rf_pred))
# Out:
# 0.7502558853633572
